# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as pl
# %matplotlib inline

# %%
x = np.linspace(-5, 5, 100)
y = x * x + np.sin(100 *x)

# %%
pl.plot(x, y);

# %% [markdown]
# # A sample program
#
# This is a function $y = x^2 + \sin(100\cdot x)$
